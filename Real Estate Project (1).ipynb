# %%
#FEATURES
#1. This project gives a sneak peak for potential buyers into california real estate market.
#2. This project puts light on the most important selling aspect of any property which is 'Location Location Location'.
#3. In this project the housing property location with respect to the ocean is observed.
#4. The location of housing properties with respect to North and West are observed and represented, so that it will be easy for customers to select property.
#5. Total population along with their income is evaluated to know and recommend properties which are most adaptive to buyers.
#6. Total bedrooms are evaluated to mention to customers appropriately depending on family size.
#7. Observed parameters in Table:

#Longitude and latitude: Continuous parameters
#Housing_median_age: Discrete parameter
#Total_rooms: Discrete parameter
#Total_bedrooms: Discrete parameter
#Population: Discrete parameter
#Households: Discrete parameter
#Median_income: Continuous parameter
#Median_house_value: Continuous parameter
#Ocean_proximity: Continuous parameter

#Nominal: Type of data used to label cariables without providing quantitative value.
#Ordinal: Categorizes and labels variables and also ranks categories in order.
#In this case the location values are used to derive location from north and west and also with respect to ocean and can be ranked independently and give to customers for property selection based on their own interests.

# %%
#First step is to read the downloaded dataset which is in Excel form.
#Also importing the matplot library for drawing graphs. 
#Pandas library is also imported for data manipulation and analysis.
#Seaborn library is used as data visualization library.

import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('C:\\Users\\harsh\\Downloads\\mtcars - mtcars (1).csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
import seaborn as sns

# %%
#QUESTION 1:
#1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.

sns.displot(df['median_incom'],color='green')
plt.title("Distribution of median_income")
plt.show()
df['median_incom'].mean()

#This distribution of average median income is Skewed right[positively skewed] graph. In this case all mean, median and mode are different.
#This graph is like this because of two reasons one is lower boundary in data set and another is if income was initially very high and income may have reduced gradually.
#Average=sum of values/number of values is the mean
# Out:
# 3.8706710029070246

# %%
#QUESTION 2:
#2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

plt.hist(df["housing_median_age"],color="green",edgecolor='white')
plt.xlabel("housing_median_age")
plt.ylabel("Newer/Older")
plt.title("Age of a the building")
plt.show()
df['housing_median_age'].mean()
#df['housing_median_age'].median()
#df['housing_median_age'].std()
#Here the housing_median_age is the number that indicates whether the house or building is new or old. 
#A lower number indicates the building is new, that is recently built. Basically it gives the age of a building. 
#Lower the number means new building.In this case:
#The main observation is medium aged buildings are more compared to new and old buildings.
# Out:
# 28.639486434108527

# %%
#QUESTION 3:
#3. Show with the help of visualization, how median_income and median_house_values are related?

plt.scatter(df['median_house_value'],df['median_incom'],marker='H',facecolor='green',edgecolor='white',s=40)
plt.xlabel('median_house_value')
plt.ylabel('median_incom')
plt.title('Relation between income and house_price')
plt.show()

#The observation which can be derived is, the more the income is accordingly the house value which is bought isalso high.

# %%
#QUESTION 4:
#4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

#First step: Identify the null values
df[df.isnull().any(axis=1)]
#In this null method all the unknown values are denoted as NA
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
#Second step: Removing the null values by using dropna() method
new_data = df.dropna(subset=['total_bedrooms'])
new_data

#Here it is observed that there is reduction in total number of rows,
#that is because null valued rows with respect to 'total_bedrooms'
#are dropped
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
#QUESTION 5:
#5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

df['total_bedrooms']=df['total_bedrooms'].fillna(df['total_bedrooms']).mean()
df

#Here the missing values are filled with mean value of 'total bedrooms'
#and rows value again comes back to orinal number but with no missing
#values
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880      537.870553
# 1        -122.22     37.86                  21         7099      537.870553
# 2        -122.24     37.85                  52         1467      537.870553
# 3        -122.25     37.85                  52         1274      537.870553
# 4        -122.25     37.85                  52         1627      537.870553
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665      537.870553
# 20636    -121.21     39.49                  18          697      537.870553
# 20637    -121.22     39.43                  17         2254      537.870553
# 20638    -121.32     39.43                  18         1860      537.870553
# 20639    -121.24     39.37                  16         2785      537.870553
#
# ...

# %%
#QUESTION 6:
#6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.

#The median is the is the middle value of the given list of data when arranged in an order.
#In this case for each column seperately median is calculated
a= df['longitude'].median()
a
# Out:
# -118.49

# %%
b= df['latitude'].median()
b
# Out:
# 34.26

# %%
c= df['housing_median_age'].median()
c
# Out:
# 29.0

# %%
d= df['total_rooms'].median()
d
# Out:
# 2127.0

# %%
e= df['total_bedrooms'].median()
e
# Out:
# 537.8705525375618

# %%
f= df['population'].median()
f
# Out:
# 1166.0

# %%
g= df['households'].median()
g
# Out:
# 409.0

# %%
h= df['median_incom'].median()
h
# Out:
# 3.5347999999999997

# %%
i= df['median_house_value'].median()
i
# Out:
# 179700.0

# %%
#QUESTION 7:
#7. Plot latitude versus longitude and explain your observations.

plt.scatter(df['latitude'],df['longitude'],facecolor='green',edgecolor='yellow',s=40)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Map')
plt.show()

#Longitude and Latitude gives the location of buildings on the map with refrence to bay area,ocean,near to ocean or whether its inland.
#And they are not dependent on each other

# %%
#QUESTION 8:
#8. Create a data set for which the ocean_proximity is ‘Near ocean’.

sns.countplot(x=df['ocean_proximity'])
plt.show()

#The inference from this graph is the number of buildings present near ocean are equal to number of buildings near bay. 
#And the buildings <1H OCEAN are the highest in number

# %%
#Now considering only those properties whose ocean_proximity is'Near ocean'.
new_data=df.loc[df["ocean_proximity"]=="NEAR OCEAN"]
new_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739      537.870553
# 1851     -124.30     41.80                  19         2672      537.870553
# 1852     -124.23     41.75                  11         3159      537.870553
# 1853     -124.21     41.77                  17         3461      537.870553
# 1854     -124.19     41.78                  15         3140      537.870553
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316      537.870553
# 20381    -118.83     34.14                  16         1956      537.870553
# 20423    -119.00     34.08                  17         1822      537.870553
# 20424    -118.75     34.18                   4        16704      537.870553
# 20425    -118.75     34.17                  18         6217      537.870553
#
# ...

# %%
#QUESTION 9:
#9. Find the mean and median of the median income for the data set created in question 8.

new_data['median_incom'].mean()

#mean is the airthmetic average of one particular column that is median_incomw
#with ocean_proximity=Near ocean
# Out:
# 4.005784800601957

# %%
#9. 
new_data['median_incom'].median()

#median of one particular column that is median_income
#with ocean_proximity=Near ocean
# Out:
# 3.64705

# %%
#QUESTION 10:
#10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less,
#it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, 
#it should be medium, otherwise it should be considered large

import numpy as np
conditions = [
              (df['total_bedrooms'] <=10),
              (df['total_bedrooms'] >=11)&(df['total_bedrooms'] <=1000),
              (df['total_bedrooms'] > 1000)
             ]
values = ['small','medium','large']
df['total_bedroom_size']=np.select(conditions,values)
df

#Here mainly condition with respect to total_bedrooms are applied and 
#the data is categorized as small,medium,big and a seperate column is created
#at the end of table.Hence there is increase in number of columns.
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880      537.870553
# 1        -122.22     37.86                  21         7099      537.870553
# 2        -122.24     37.85                  52         1467      537.870553
# 3        -122.25     37.85                  52         1274      537.870553
# 4        -122.25     37.85                  52         1627      537.870553
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665      537.870553
# 20636    -121.21     39.49                  18          697      537.870553
# 20637    -121.22     39.43                  17         2254      537.870553
# 20638    -121.32     39.43                  18         1860      537.870553
# 20639    -121.24     39.37                  16         2785      537.870553
#
# ...

# %%
#OBSERVATIONS:
#1. The median income is Skewed right[positively skewed] graph.
#2. The median_house_value has outliers.
#3. The total_bedrooms columns had some undefined values.
#4. The latitude and longitude are independent of each other.
#5. The ocean proximity column suggests that there are more properties at <1H OCEAN.
